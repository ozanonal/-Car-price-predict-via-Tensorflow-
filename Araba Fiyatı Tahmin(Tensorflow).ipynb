# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
data = pd.read_csv("audi.csv")

# %%
data
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0        A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1        A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2        A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3        A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4        A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6         1.0
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6         1.0
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6         1.0
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9         1.4
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9         1.4
#
# ...

# %%
data.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0

# %%
data.tail()
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6         1.0
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6         1.0
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6         1.0
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9         1.4
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9         1.4

# %%
data.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10668.000000   10668.000000   10668.000000  10668.000000  10668.000000
# mean    2017.100675   22896.685039   24827.244001    126.011436     50.770022
# std        2.167494   11714.841888   23505.257205     67.170294     12.949782
# min     1997.000000    1490.000000       1.000000      0.000000     18.900000
# 25%     2016.000000   15130.750000    5968.750000    125.000000     40.900000
# 50%     2017.000000   20200.000000   19000.000000    145.000000     49.600000
# 75%     2019.000000   27990.000000   36464.500000    145.000000     58.900000
# max     2020.000000  145000.000000  323000.000000    580.000000    188.300000
#
#          engineSize
# count  10668.000000
# mean       1.930709
# std        0.602957
# min        0.000000
# 25%        1.500000
# 50%        2.000000
# 75%        2.000000
# max        6.300000

# %%
data.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
plt.figure(figsize = (9,5))
sbn.distplot(data["price"])
# Out:
# C:\Users\OZAN\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sbn.countplot(data["year"])
# Out:
# C:\Users\OZAN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
sbn.scatterplot(x="mileage", y="price", data = data)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='price'>

# %% [markdown]
# Kilometre arttıkça araba fiyatlarının düştüğünü fiyatların düştüğünü görmekteyiz.

# %%
data.sort_values("price", ascending = False). head(30)
# Out:
#       model  year   price transmission  mileage fuelType  tax   mpg  \
# 4783     R8  2020  145000    Semi-Auto     2000   Petrol  145  21.1
# 2255     R8  2020  137995    Semi-Auto       70   Petrol  145  21.1
# 4179     R8  2019  137500    Semi-Auto       10   Petrol  150  21.4
# 3367     R8  2019  135000    Automatic     1000   Petrol  145  32.8
# 5459     R8  2020  133900    Semi-Auto      333   Petrol  145  21.4
# 1646     R8  2019  129000    Semi-Auto     4000   Petrol  145  21.4
# 10468    R8  2019  125000    Automatic    13663   Petrol  150  21.4
# 4925     R8  2019  125000    Semi-Auto      500   Petrol  145  21.4
# 3359     R8  2019  125000    Automatic      100   Petrol  145  24.1
# 7445     R8  2019  119995    Semi-Auto     7800   Petrol  145  21.4
# 7128     R8  2019  119450    Automatic     3000   Petrol  145  21.4
# 4742     R8  2019  117990    Automatic    11936   Petrol  145  21.4
# 5707     R8  2019  116000    Automatic     2369   Petrol  145  22.6
# ...

# %%
data.sort_values("price", ascending = True). head(30)
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 10588    A3  2003   1490    Automatic   101000   Diesel  240  44.5         1.9
# 10552    A4  2004   1699       Manual   110000   Diesel  315  36.2         2.5
# 7795     A3  2005   1975       Manual   104000   Petrol  240  38.1         2.0
# 10108    TT  2002   1990       Manual   131925   Petrol  325  30.1         1.8
# 7404     A3  2009   2490       Manual   152034   Diesel  150  55.4         1.9
# 9822     A6  2008   2490       Manual   323000   Diesel  200  44.1         2.0
# 10158    A2  2003   2490       Manual   100000   Diesel   30  65.7         1.4
# 9897     A3  2005   2495       Manual   122000   Diesel  150  53.3         0.0
# 9359     A6  2003   2495       Manual   129000   Diesel  325  31.7         2.5
# 7750     A6  2003   2495    Automatic   117000   Diesel  290  39.8         2.5
# 10259    A6  2007   2600       Manual   127700   Diesel  205  44.1         2.0
# ...

# %%
len(data)
# Out:
# 10668

# %%
len(data)*0.01
# Out:
# 106.68

# %%
doksanDokuzlukKesim = data.sort_values("price", ascending = False).iloc[106:]

# %%
doksanDokuzlukKesim.head(20)
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 7221     A5  2020  59995    Semi-Auto     2000   Diesel  150  40.9         3.0
# 222      Q7  2019  59995    Automatic       10   Diesel  145  33.2         3.0
# 5129     Q7  2019  59990    Automatic     3988   Diesel  145  32.8         3.0
# 4100    RS4  2019  59990    Automatic     5121   Petrol  145  29.1         2.9
# 4669     Q7  2020  59990    Semi-Auto      799   Diesel  145  33.2         3.0
# 4947     Q7  2020  59990    Semi-Auto     6000   Diesel  145  33.2         3.0
# 9407     Q7  2019  59990    Automatic     1335   Diesel  145  33.2         3.0
# 1967     Q8  2019  59990    Semi-Auto     5000   Diesel  145  32.8         3.0
# 4722     Q7  2020  59990    Semi-Auto     6000   Diesel  145  33.2         3.0
# 7475     R8  2014  59990    Automatic    31930   Petrol  580  21.9         5.2
# 7845     A6  2018  59950    Automatic    22000   Petrol  145  29.4         4.0
# ...

# %%
plt.figure(figsize = (9,5))
sbn.distplot(doksanDokuzlukKesim["price"])
# Out:
# C:\Users\OZAN\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [markdown]
# Yüksek fiyatlı arabalar grafikte dağınık bir şekilde yer aldığı için en yüksek fiyattaki %1' lik kesimdeki arabaları veriden attım.

# %%
doksanDokuzlukKesim.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  10562.000000  10562.000000   10562.000000  10562.000000  10562.000000
# mean    2017.079909  22331.520640   25012.921038    125.730449     50.977978
# std        2.166547  10079.220417   23540.812433     67.199298     12.837371
# min     1997.000000   1490.000000       5.000000      0.000000     18.900000
# 25%     2016.000000  15000.000000    6000.000000    125.000000     40.900000
# 50%     2017.000000  20000.000000   19298.000000    145.000000     49.600000
# 75%     2019.000000  27847.750000   36715.000000    145.000000     58.900000
# max     2020.000000  59995.000000  323000.000000    580.000000    188.300000
#
#          engineSize
# count  10562.000000
# mean       1.912412
# std        0.571433
# min        0.000000
# 25%        1.500000
# 50%        2.000000
# 75%        2.000000
# max        6.300000

# %%
data.groupby("year").mean()["price"]
# Out:
# year
# 1997     4650.000000
# 1998     4999.000000
# 2002     2433.000000
# 2003     3408.333333
# 2004     5053.600000
# 2005     3490.714286
# 2006     6499.111111
# 2007     7325.250000
# 2008     6281.428571
# 2009     6281.956522
# 2010     7224.093750
# 2011     8944.808511
# 2012     9860.811765
# 2013    11690.790378
# 2014    13890.659955
# 2015    15128.235235
# 2016    16908.725051
# 2017    19951.624289
# 2018    26296.707176
# 2019    30410.752268
# 2020    35967.067039
# Name: price, dtype: float64

# %%
doksanDokuzlukKesim.groupby("year").mean()["price"]
# Out:
# year
# 1997     4650.000000
# 1998     4999.000000
# 2002     2433.000000
# 2003     3408.333333
# 2004     5053.600000
# 2005     3490.714286
# 2006     6499.111111
# 2007     7325.250000
# 2008     6281.428571
# 2009     6281.956522
# 2010     7224.093750
# 2011     8944.808511
# 2012     9860.811765
# 2013    11690.790378
# 2014    13890.659955
# 2015    15128.235235
# 2016    16847.266055
# 2017    19908.537506
# 2018    25465.005896
# 2019    29689.902060
# 2020    33201.278274
# Name: price, dtype: float64

# %%
data = doksanDokuzlukKesim

# %%
data.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  10562.000000  10562.000000   10562.000000  10562.000000  10562.000000
# mean    2017.079909  22331.520640   25012.921038    125.730449     50.977978
# std        2.166547  10079.220417   23540.812433     67.199298     12.837371
# min     1997.000000   1490.000000       5.000000      0.000000     18.900000
# 25%     2016.000000  15000.000000    6000.000000    125.000000     40.900000
# 50%     2017.000000  20000.000000   19298.000000    145.000000     49.600000
# 75%     2019.000000  27847.750000   36715.000000    145.000000     58.900000
# max     2020.000000  59995.000000  323000.000000    580.000000    188.300000
#
#          engineSize
# count  10562.000000
# mean       1.912412
# std        0.571433
# min        0.000000
# 25%        1.500000
# 50%        2.000000
# 75%        2.000000
# max        6.300000

# %%
data.groupby("year").mean()["price"]
# Out:
# year
# 1997     4650.000000
# 1998     4999.000000
# 2002     2433.000000
# 2003     3408.333333
# 2004     5053.600000
# 2005     3490.714286
# 2006     6499.111111
# 2007     7325.250000
# 2008     6281.428571
# 2009     6281.956522
# 2010     7224.093750
# 2011     8944.808511
# 2012     9860.811765
# 2013    11690.790378
# 2014    13890.659955
# 2015    15128.235235
# 2016    16847.266055
# 2017    19908.537506
# 2018    25465.005896
# 2019    29689.902060
# 2020    33201.278274
# Name: price, dtype: float64

# %%
data.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 7221    A5  2020  59995    Semi-Auto     2000   Diesel  150  40.9         3.0
# 222     Q7  2019  59995    Automatic       10   Diesel  145  33.2         3.0
# 5129    Q7  2019  59990    Automatic     3988   Diesel  145  32.8         3.0
# 4100   RS4  2019  59990    Automatic     5121   Petrol  145  29.1         2.9
# 4669    Q7  2020  59990    Semi-Auto      799   Diesel  145  33.2         3.0

# %%
data.tail()
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 7404     A3  2009   2490       Manual   152034   Diesel  150  55.4         1.9
# 10108    TT  2002   1990       Manual   131925   Petrol  325  30.1         1.8
# 7795     A3  2005   1975       Manual   104000   Petrol  240  38.1         2.0
# 10552    A4  2004   1699       Manual   110000   Diesel  315  36.2         2.5
# 10588    A3  2003   1490    Automatic   101000   Diesel  240  44.5         1.9

# %%
dataFrame = data.drop("transmission", axis =1)

# %%
dataFrame1 = dataFrame.drop("fuelType", axis = 1)

# %%
dataFramee = dataFrame1.drop("model", axis = 1)

# %%
dataFramee
# Out:
#        year  price  mileage  tax   mpg  engineSize
# 7221   2020  59995     2000  150  40.9         3.0
# 222    2019  59995       10  145  33.2         3.0
# 5129   2019  59990     3988  145  32.8         3.0
# 4100   2019  59990     5121  145  29.1         2.9
# 4669   2020  59990      799  145  33.2         3.0
# ...     ...    ...      ...  ...   ...         ...
# 7404   2009   2490   152034  150  55.4         1.9
# 10108  2002   1990   131925  325  30.1         1.8
# 7795   2005   1975   104000  240  38.1         2.0
# 10552  2004   1699   110000  315  36.2         2.5
# 10588  2003   1490   101000  240  44.5         1.9
#
# [10562 rows x 6 columns]

# %%
y = dataFramee["price"].values

# %%
y
# Out:
# array([59995, 59995, 59990, ...,  1975,  1699,  1490], dtype=int64)

# %%
x = dataFramee.drop("price", axis = 1).values

# %%
x
# Out:
# array([[2.020e+03, 2.000e+03, 1.500e+02, 4.090e+01, 3.000e+00],
#        [2.019e+03, 1.000e+01, 1.450e+02, 3.320e+01, 3.000e+00],
#        [2.019e+03, 3.988e+03, 1.450e+02, 3.280e+01, 3.000e+00],
#        ...,
#        [2.005e+03, 1.040e+05, 2.400e+02, 3.810e+01, 2.000e+00],
#        [2.004e+03, 1.100e+05, 3.150e+02, 3.620e+01, 2.500e+00],
#        [2.003e+03, 1.010e+05, 2.400e+02, 4.450e+01, 1.900e+00]])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=1)

# %%
len(x_train)
# Out:
# 7393

# %%
len(x_test)
# Out:
# 3169

# %% [markdown]
# Burada görüldüğü üzere %30' luk bir kısmı teste ayırmış bulunmaktayım.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_test = scaler.transform(x_test)

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
x_train.shape
# Out:
# (7393, 5)

# %% [markdown]
# Şu anda burada 7393 verimiz ve 5 tane özelliğimiz var. Bu durumda 5 tane layerden başlatmamız uygun olur diye düşünerek işleme devam edeceğim.

# %% [markdown]
# 4 tane derin ağ olacak şekilde katman ekleyeceğim.

# %%
model = Sequential()

model.add(Dense(5, activation = "relu"))
model.add(Dense(5, activation = "relu"))
model.add(Dense(5, activation = "relu"))
model.add(Dense(5, activation = "relu"))

model.add(Dense(1))

model.compile(optimizer = "adam", loss="mse")

# %%
model.fit(x=x_train, y=y_train, validation_data = (x_test,y_test), batch_size = 250, epochs=310)
# Out:
# Epoch 1/310
# 30/30 [==============================] - 0s 7ms/step - loss: 598388864.0000 - val_loss: 604643776.0000
# Epoch 2/310
# 30/30 [==============================] - 0s 3ms/step - loss: 598374656.0000 - val_loss: 604628352.0000
# Epoch 3/310
# 30/30 [==============================] - 0s 2ms/step - loss: 598356160.0000 - val_loss: 604604800.0000
# Epoch 4/310
# 30/30 [==============================] - 0s 2ms/step - loss: 598326016.0000 - val_loss: 604565312.0000
# Epoch 5/310
# 30/30 [==============================] - 0s 2ms/step - loss: 598274496.0000 - val_loss: 604496960.0000
# Epoch 6/310
# 30/30 [==============================] - 0s 2ms/step - loss: 598184576.0000 - val_loss: 604376512.0000
# Epoch 7/310
# 30/30 [==============================] - 0s 2ms/step - loss: 598026688.0000 - val_loss: 604167360.0000
# Epoch 8/310
# 30/30 [==============================] - 0s 2ms/step - loss: 597757504.0000 - val_loss: 603818176.0000
# Epoch 9/310
# ...

# %%
lost = pd.DataFrame(model.history.history)

# %%
lost.head()
# Out:
#           loss     val_loss
# 0  598388864.0  604643776.0
# 1  598374656.0  604628352.0
# 2  598356160.0  604604800.0
# 3  598326016.0  604565312.0
# 4  598274496.0  604496960.0

# %%
lost.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
predict1 = model.predict(x_test)

# %%
predict1
# Out:
# array([[28055.617],
#        [29721.008],
#        [22253.617],
#        ...,
#        [20806.219],
#        [32230.967],
#        [17104.967]], dtype=float32)

# %%
mean_absolute_error(y_test, predict1)
# Out:
# 2740.569542582428

# %%
dataFramee.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  10562.000000  10562.000000   10562.000000  10562.000000  10562.000000
# mean    2017.079909  22331.520640   25012.921038    125.730449     50.977978
# std        2.166547  10079.220417   23540.812433     67.199298     12.837371
# min     1997.000000   1490.000000       5.000000      0.000000     18.900000
# 25%     2016.000000  15000.000000    6000.000000    125.000000     40.900000
# 50%     2017.000000  20000.000000   19298.000000    145.000000     49.600000
# 75%     2019.000000  27847.750000   36715.000000    145.000000     58.900000
# max     2020.000000  59995.000000  323000.000000    580.000000    188.300000
#
#          engineSize
# count  10562.000000
# mean       1.912412
# std        0.571433
# min        0.000000
# 25%        1.500000
# 50%        2.000000
# 75%        2.000000
# max        6.300000

# %% [markdown]
# Burada, 22331 olan ortalama fiyattan 2740 kadar sapabileceğimiz anlamına gelir.

# %%
2740/22331
# Out:
# 0.12269938650306748

# %% [markdown]
#  %12 lik bir farkla karşılaştık. Bu farkı biraz daha düşürmeye çalışacağım.

# %%
plt.scatter(y_test, predict1)
plt.plot(y_test, y_test, "r-")

# %%
model1 = Sequential()

model1.add(Dense(6, activation = "relu"))
model1.add(Dense(6, activation = "relu"))
model1.add(Dense(6, activation = "relu"))
model1.add(Dense(1, activation = "relu"))

model1.add(Dense(1))

model1.compile(optimizer = "adam", loss="mse")

# %%
model1.fit(x=x_train, y=y_train, validation_data = (x_test,y_test), batch_size = 250, epochs=350)
# Out:
# Epoch 1/350
# 30/30 [==============================] - 0s 8ms/step - loss: 598393152.0000 - val_loss: 604648640.0000
# Epoch 2/350
# 30/30 [==============================] - 0s 2ms/step - loss: 598378560.0000 - val_loss: 604631104.0000
# Epoch 3/350
# 30/30 [==============================] - 0s 2ms/step - loss: 598357632.0000 - val_loss: 604605504.0000
# Epoch 4/350
# 30/30 [==============================] - 0s 2ms/step - loss: 598326656.0000 - val_loss: 604566912.0000
# Epoch 5/350
# 30/30 [==============================] - 0s 2ms/step - loss: 598279616.0000 - val_loss: 604508032.0000
# Epoch 6/350
# 30/30 [==============================] - 0s 2ms/step - loss: 598201536.0000 - val_loss: 604399488.0000
# Epoch 7/350
# 30/30 [==============================] - 0s 2ms/step - loss: 598049152.0000 - val_loss: 604186880.0000
# Epoch 8/350
# 30/30 [==============================] - 0s 2ms/step - loss: 597773440.0000 - val_loss: 603834496.0000
# Epoch 9/350
# ...

# %%
lost1 = pd.DataFrame(model1.history.history)

# %%
lost1
# Out:
#             loss     val_loss
# 0    598393152.0  604648640.0
# 1    598378560.0  604631104.0
# 2    598357632.0  604605504.0
# 3    598326656.0  604566912.0
# 4    598279616.0  604508032.0
# ..           ...          ...
# 345   15248960.0   15049079.0
# 346   15261457.0   15071754.0
# 347   15248774.0   15020081.0
# 348   15237022.0   15041105.0
# 349   15236478.0   15081852.0
#
# [350 rows x 2 columns]

# %%
lost1.plot()
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
predict2 = model1.predict(x_test)

# %%
predict2
# Out:
# array([[27532.158],
#        [29145.41 ],
#        [21189.377],
#        ...,
#        [20019.8  ],
#        [32185.398],
#        [17221.975]], dtype=float32)

# %%
mean_absolute_error(y_test, predict2)
# Out:
# 2598.9790073173886

# %%
dataFramee.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  10562.000000  10562.000000   10562.000000  10562.000000  10562.000000
# mean    2017.079909  22331.520640   25012.921038    125.730449     50.977978
# std        2.166547  10079.220417   23540.812433     67.199298     12.837371
# min     1997.000000   1490.000000       5.000000      0.000000     18.900000
# 25%     2016.000000  15000.000000    6000.000000    125.000000     40.900000
# 50%     2017.000000  20000.000000   19298.000000    145.000000     49.600000
# 75%     2019.000000  27847.750000   36715.000000    145.000000     58.900000
# max     2020.000000  59995.000000  323000.000000    580.000000    188.300000
#
#          engineSize
# count  10562.000000
# mean       1.912412
# std        0.571433
# min        0.000000
# 25%        1.500000
# 50%        2.000000
# 75%        2.000000
# max        6.300000

# %%
2598/22331
# Out:
# 0.11634051318794501

# %% [markdown]
# Farkı azda olsa düşürmeyi başardım.

# %%
plt.scatter(y_test, predict2)
plt.plot(y_test, y_test, "r-")

# %% [markdown]
# Burada verinin içerisinden yüksek fiyatlı bir arabayı çıkarıp, değerini tahmin ettirmeye çalışırsak;

# %%
dataFramee.head(10)
# Out:
#       year  price  mileage  tax   mpg  engineSize
# 7221  2020  59995     2000  150  40.9         3.0
# 222   2019  59995       10  145  33.2         3.0
# 5129  2019  59990     3988  145  32.8         3.0
# 4100  2019  59990     5121  145  29.1         2.9
# 4669  2020  59990      799  145  33.2         3.0
# 4947  2020  59990     6000  145  33.2         3.0
# 9407  2019  59990     1335  145  33.2         3.0
# 1967  2019  59990     5000  145  32.8         3.0
# 4722  2020  59990     6000  145  33.2         3.0
# 7475  2014  59990    31930  580  21.9         5.2

# %%
dataFramee.iloc[9]
# Out:
# year           2014.0
# price         59990.0
# mileage       31930.0
# tax             580.0
# mpg              21.9
# engineSize        5.2
# Name: 7475, dtype: float64

# %%
newCar = dataFramee.drop("price", axis = 1).iloc[9]

# %%
newCar
# Out:
# year           2014.0
# mileage       31930.0
# tax             580.0
# mpg              21.9
# engineSize        5.2
# Name: 7475, dtype: float64

# %%
newCar = scaler.transform(newCar.values.reshape(-1,5))

# %%
newCar
# Out:
# array([[0.72727273, 0.09884054, 1.        , 0.01538462, 0.82539683]])

# %%
model.predict(newCar)
# Out:
# array([[53768.78]], dtype=float32)

# %% [markdown]
# Burada verinin içerisinde olan bir arabayı çıkarıp değerini tahmin ettirdiğimde, normalde 59990 değerinde olan bu arabanın fiyatını 53768 olarak hesapladı.

# %% [markdown]
# Tabiki eğer istersek, bu değeri daha fazla birbirine yaklaştırmamız tensorflow' da ayarları değiştirerek mümkün olabilir.
